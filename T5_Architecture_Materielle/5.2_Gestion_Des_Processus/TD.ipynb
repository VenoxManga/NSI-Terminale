# %% [markdown]
# # Exercice 1
# 1. Deadlock

# %% [markdown]
# # Exercice 2
#
# ## Partie A
#
# 1. b
# 2. c
# 3. b
# 4. d
#
# ## Partie B
#
# **Q1** *0* P3 *1* P3 *2* P2 *3* P1 *4* P1 *5* P1 *6* P2 *7* P2 *8* P3 *9* P3 *10*
#
# **Q2** Scénario 2
