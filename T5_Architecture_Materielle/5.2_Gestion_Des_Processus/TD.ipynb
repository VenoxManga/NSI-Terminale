# %% [markdown]
# # Exercice 1
# 1. Deadlock

# %% [markdown]
# # Exercice 2
#
# ### Partie A
#
# 1. b
# 2. c
# 3. b
# 4. d
#
# ### Partie B
#
# **Q1** *0* P3 *1* P3 *2* P2 *3* P1 *4* P1 *5* P1 *6* P2 *7* P2 *8* P3 *9* P3 *10*
#
# **Q2** Scénario 2

# %% [markdown]
# # Exercice 3
#
# ### Partie A
#
# **Q1** Le programme 1 attends un *modem* récuperé par le Programme 2 pendant que celui-ci attends *l'imprimante* récuperé par le Programme 3. Chacun des programmes attends une ressource avant de pouvoir executer son code et relacher le sressource spour le sautres. Cela mène a un Deadlock.
#
# **Q2** Inverser les deux premières lignes pour permettre la récupération du code par d'autres programmes.
#
# **Q3** Bloqué.
#
# ### Partie B
#
# **Q1** ps -ef
#
# **Q2** PPID 831
#
# **Q3** PID 6211

# %% [markdown]
# # Exercice 4
#
# **Q1**.a un programme élu est celui qui est choisi par le scheduler. C'est à ce programme d'être executé.
#
# **Q1**.b![EtatProcessus1.png](attachment:EtatProcessus1.png)
#
# **Q2**.a First In, First Out
#
# **Q2**.b

# %% [markdown]
# # Exercice 5
#
# **1**.a Proposition 2
#
# **1**.b cd lycee
#
# **1**.c mkdir algorithmique
#
# **1**.d
